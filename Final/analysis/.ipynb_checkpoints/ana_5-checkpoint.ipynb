# %% [markdown]
# # Analysis 5
#   * Which genres got maximum >= 7 ratings
#   * Which genres are most profitable

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
file = pd.read_csv('../data/movie_metadata.csv')

# %%
file['profit'] = file['gross'] - file['budget']

# %%
data = file[['genres','movie_title','language','title_year','imdb_score','duration','profit']]
data.head()
# Out:
#                             genres  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary
#
#                                          movie_title language  title_year  \
# 0                                            Avatar   English      2009.0
# 1          Pirates of the Caribbean: At World's End   English      2007.0
# 2                                           Spectre   English      2015.0
# 3                             The Dark Knight Rises   English      2012.0
# 4  Star Wars: Episode VII - The Force Awakens    ...      NaN         NaN
#
#    imdb_score  duration       profit
# 0         7.9     178.0  523505847.0
# 1         7.1     169.0    9404152.0
# 2         6.8     148.0  -44925825.0
# 3         8.5     164.0  198130642.0
# 4         7.1       NaN          NaN

# %%
s = data['genres'].str.split('|').apply(Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'genres'
del data['genres']
df = data.join(s)
df1 = df[df['imdb_score']>=7]
df1.head()
# Out:
#                                  movie_title language  title_year  imdb_score  \
# 0                                    Avatar   English      2009.0         7.9
# 0                                    Avatar   English      2009.0         7.9
# 0                                    Avatar   English      2009.0         7.9
# 0                                    Avatar   English      2009.0         7.9
# 1  Pirates of the Caribbean: At World's End   English      2007.0         7.1
#
#    duration       profit     genres
# 0     178.0  523505847.0     Action
# 0     178.0  523505847.0  Adventure
# 0     178.0  523505847.0    Fantasy
# 0     178.0  523505847.0     Sci-Fi
# 1     169.0    9404152.0     Action

# %%
df2 = (pd.DataFrame(df1.groupby('genres').movie_title.nunique())).sort_values('movie_title', ascending=False )
df2[['movie_title']].plot.barh(stacked=True, title = 'Genres having 7 or more ratings', figsize=(8, 8));

# %%
df3 = df[['movie_title', 'profit','genres']]
# Checking for NaN
df3.loc[df3['genres'] == 'News']
df4 = df3.groupby(['genres']).mean()
df4['profit_million'] = df4['profit']/1000000
del df4['profit']
df4.sort_values('profit_million', ascending=False, inplace = True )
df4[['profit_million']].plot.barh(stacked=True, title = 'Genres by profit (US$ million)', figsize=(8, 8));

# %%
df2.to_csv('ana_5/ana_5_7_imdb_score.csv',index=True,sep=',')
df4.to_csv('ana_5/ana_5_profits.csv',index=True,sep=',')

# %% [markdown]
# # Inference
#    * From the above analysis we can certainly say that genres with more imdb score need not be the most profitable genres to produce movies in.
#    * As we can see that imdb score is not directly proportional to box office collection.
